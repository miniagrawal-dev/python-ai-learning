# %% [markdown]
# <a href="https://colab.research.google.com/github/miniagrawal-dev/python-ai-learning/blob/main/01-python-basics/01_variables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = "mini"
age = 30
YOE = 9

print(name)
print(age)
print(YOE)

print(type(name))
print(type(age))
print(type(YOE))

experience = 9
target_experience = 15
print(target_experience - experience)

x = 10
print(type(x))

x = "Python"
print(type(x))

x = 3.14
print(type(x))
# Out:
# mini
# 30
# 9
# <class 'str'>
# <class 'int'>
# <class 'int'>
# 6
# <class 'int'>
# <class 'str'>
# <class 'float'>

# %%
text = "Artificial Intelligence"

print(len(text))
print(text[0])
print(text[-1])
print(text[0:10])
print(text[-5:])
print(text[::-1])


name = "Mini"
role = "Senior Software Engineer"
experience = 9

print(f"""
My name is {name}. I am a {role} with {experience} years of experience.
""")

user_question = "What is semantic search?"
str = f"""
You are an AI teacher.

Explain the following concept to a software engineer who knows Java but is new to AI.
Concept: {user_question}

Use a simple example
"""
print(str)
# Out:
# 23
# A
# e
# Artificial
# gence
# ecnegilletnI laicifitrA
#
# My name is Mini. I am a Senior Software Engineer with 9 years of experience.
#
#
# You are an AI teacher.
#
# Explain the following concept to a software engineer who knows Java but is new to AI.
# Concept: What is semantic search?
#
# Use a simple example
