# %% [markdown]
# <a href="https://colab.research.google.com/github/miniagrawal-dev/python-ai-learning/blob/main/01-python-basics/01_variables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = "Mini"
experience = 9
role = "Senior Software Engineer"
learning_ai = True

print(name)
print(experience)
print(role)
print(learning_ai)

print(type(name))
print(type(experience))
print(type(role))
print(type(learning_ai))
# Out:
# Mini
# 9
# Senior Software Engineer
# True
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'bool'>
