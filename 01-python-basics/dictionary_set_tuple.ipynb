# %% [markdown]
# <a href="https://colab.research.google.com/github/miniagrawal-dev/python-ai-learning/blob/main/01-python-basics/dictionary_set_tuple.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
model_config = {
"model":"x",
"temperature" : 37.1,
"max_tokens" : 1,
"provider" : "openai"
}

print(model_config)
# Out:
# {'model': 'x', 'temperature': 37.1, 'max_tokens': 1, 'provider': 'openai'}

# %%
user = {
    "name": "Mini",
    "role": "Software Engineer"
}

print(user["name"])
print(user.get("city"))
print(user.get("city", "Unknown"))
# Out:
# Mini
# None
# Unknown

# %%
profile = {
    "name": "Mini",
    "experience": 9
}

profile["language"]=  "python"
profile["experience"] = 10
profile["goal"]=  "AI Engineer"
print(profile)
# Out:
# {'name': 'Mini', 'experience': 10, 'language': 'python', 'goal': 'AI Engineer'}

# %%
documents = [
    {"title": "Python", "score": 0.91},
    {"title": "RAG", "score": 0.95},
    {"title": "Agents", "score": 0.88}
]

for document in documents :
  print(document["title"] , document["score"])

for document in documents :
    if document["score"] > 0.90 :
       print(document["title"] , document["score"])
# Out:
# Python 0.91
# RAG 0.95
# Agents 0.88
# Python 0.91
# RAG 0.95

# %%
words = ["python", "java", "kafka", "rag"]

comp = {str : len(str) for str in words}

print(comp)
# Out:
# {'python': 6, 'java': 4, 'kafka': 5, 'rag': 3}

# %%
result = ("RAG", 0.95)
x, y = result
print(x)
print(y)
# Out:
# RAG
# 0.95

# %%
document_ids = [101, 102, 101, 103, 102, 104, 101]

set1 = {id for id in document_ids}

document = [val for val in set1]

print(document)
# Out:
# [104, 101, 102, 103]

# %%
agent_state = {
    "user": {
        "name": "Mini"
    },
    "messages": [],
    "tools_used": __builtins__.set(),
    "metadata": {
        "session_id": 123
    }
}

agent_state["messages"].append({"role": "sse"})
agent_state["tools_used"].add("search")
agent_state["tools_used"].add("calculator")

print(agent_state["user"]["name"])
print(agent_state["messages"])
print(agent_state["tools_used"])
# Out:
# Mini
# [{'role': 'sse'}]
# {'search', 'calculator'}
